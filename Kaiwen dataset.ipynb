# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("shared_documents/FFG_Hackathon_Country_Level_Data.csv")

# %%
electricPower=dataset['EG.USE.COMM.FO.ZS']
co2=dataset['EN.ATM.CO2E.KT']


country=dataset['Country Name'].drop_duplicates()

# %%
electric=dataset.groupby('Year').agg({'EG.USE.COMM.FO.ZS':['sum']}).reset_index()
c02data=dataset.groupby('Year').agg({'EN.ATM.CO2E.KT':['sum']}).reset_index()

# %%
co2[dataset['Country Name']=='Albania']
emissionDecrease=[0]*country.size

# %%
j=0
for i in enumerate(country):
    temp=co2[dataset['Country Name']==i[1]].tolist()
    emissionDecrease[j]=[i[1],(temp[9]-temp[0])/temp[0]*100]
    j=j+1

# %%
print(type(emissionDecrease))
print(emissionDecrease[0])
# Out:
# <class 'list'>
# ['Albania', 15.499533146591965]

# %%
def Sort(sub_li):
  
    # reverse = None (Sorts in Ascending order)
    # key is set to sort using second element of 
    # sublist lambda has been used
    sub_li.sort(key = lambda x: x[1])
    return sub_li

# %%
output=Sort(emissionDecrease)

# %%
print(output[0:5])
print(output[125:130])
# Out:
# [['Denmark', -36.831365690132635], ['Greece', -36.45117945655419], ['Finland', -28.034748590495923], ['Croatia', -26.60818713450293], ['Bulgaria', -20.18245614035088]]
# [['Senegal', 110.40339702760087], ['Togo', 113.02083333333337], ['Zambia', 166.5399239543726], ['Niger', 179.18781725888323], ['Nepal', 248.24684431977562]]

# %%
output1=output[0:5]
output2=output[125:130]

# %%
column0=[row[0] for row in output1]
column1=[row[1] for row in output1]
column00=[row[0] for row in output2]
column01=[row[1] for row in output2]

# %%
plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column00,column01)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,column1)
plt.show()

# %%
c02databycountry=dataset.groupby('Country Name')

# %%
electric.plot(x = 'Year', y = ('EG.USE.COMM.FO.ZS','sum'), kind = 'bar')
c02data.plot(x = 'Year', y = ('EN.ATM.CO2E.KT','sum'), kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
c02databycountry.plot(x = 'Country Name', y = ('EN.ATM.CO2E.KT','sum'), kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('EN.ATM.CO2E.KT', 'sum')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-80adb104350a> in <module>
# ...

# %%
aa=co2liquidfuel[dataset['Country Name']=='Denmark'].tolist()
ab=oilgascoal[dataset['Country Name']=='Denmark'].tolist()
ac=hydroelectric[dataset['Country Name']=='Denmark'].tolist()
ad=naturalgas[dataset['Country Name']=='Denmark'].tolist()
ae=nuclear[dataset['Country Name']=='Denmark'].tolist()
af=oil[dataset['Country Name']=='Denmark'].tolist()
ag=renew[dataset['Country Name']=='Denmark'].tolist()

# %%
co2liquidfuel[dataset['Country Name']==column0[0]].tolist()
# Out:
# [50.59263404,
#  47.68953463,
#  48.61336338,
#  43.75997118,
#  39.67186125,
#  34.32787206,
#  41.13634401,
#  34.37733035,
#  24.54485784,
#  nan]

# %%
co2liquidfuel=dataset['EG.ELC.COAL.ZS']
oilgascoal=dataset['EG.ELC.FOSL.ZS']
hydroelectric=dataset['EG.ELC.HYRO.ZS']
naturalgas=dataset['EG.ELC.NGAS.ZS']
nuclear=dataset['EG.ELC.NUCL.ZS']
oil=dataset['EG.ELC.PETR.ZS']
renew=dataset['EG.ELC.RNWX.ZS']

# %%
temp1=nuclear[dataset['Country Name']=='Denmark'].tolist()
print(nuclear)
liquidfuelgood=(temp1[8]-temp1[0])
print(liquidfuelgood)
# Out:
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        6.718801
# 4       43.285860
#           ...
# 1305          NaN
# 1306          NaN
# 1307          NaN
# 1308          NaN
# 1309          NaN
# Name: EG.ELC.NUCL.ZS, Length: 1310, dtype: float64
# 0.0

# %%
temp1=co2liquidfuel[dataset['Country Name']=='Denmark'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=oilgascoal[dataset['Country Name']=='Denmark'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=hydroelectric[dataset['Country Name']=='Denmark'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=naturalgas[dataset['Country Name']=='Denmark'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)


temp1=oil[dataset['Country Name']=='Denmark'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=renew[dataset['Country Name']=='Denmark'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)
# Out:
# -51.48531341421337
# -55.55118483833081
# -12.686732570111484
# -64.94951285054019
# -66.99389782499495
# 150.36354583601363

# %%
temp1=co2liquidfuel[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=oilgascoal[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=hydroelectric[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=naturalgas[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=nuclear[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=oil[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)

temp1=renew[dataset['Country Name']=='France'].tolist()
liquidfuelgood=(temp1[8]-temp1[0])/temp1[0]*100
print(liquidfuelgood)
# Out:
# -56.80466006385008
# -39.410741458068536
# -5.449367462657185
# -9.93125890474316
# -0.47619163175749385
# -65.0003990882449
# 320.68408784708674

# %%
liquidfuelgood=[0]*5
liquidfuelbad=[0]*5
for i in range(0, 5):
    temp1=co2liquidfuel[dataset['Country Name']==column0[i]].tolist()
    temp2=co2liquidfuel[dataset['Country Name']==column00[i]].tolist()
    liquidfuelgood[i]=(temp1[8]-temp1[0])
    liquidfuelbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,liquidfuelbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,liquidfuelgood)
plt.show()

# %%
oilgascoalgood=[0]*5
oilgascoalbad=[0]*5
for i in range(0, 5):
    temp1=oilgascoal[dataset['Country Name']==column0[i]].tolist()
    temp2=oilgascoal[dataset['Country Name']==column00[i]].tolist()
    oilgascoalgood[i]=(temp1[8]-temp1[0])
    oilgascoalbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,oilgascoalbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,oilgascoalgood)
plt.show()

# %%
liquidfuelgood=[0]*5
liquidfuelbad=[0]*5
for i in range(0, 5):
    temp1=co2liquidfuel[dataset['Country Name']==column0[i]].tolist()
    temp2=co2liquidfuel[dataset['Country Name']==column00[i]].tolist()
    liquidfuelgood[i]=(temp1[8]-temp1[0])
    liquidfuelbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,liquidfuelbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,liquidfuelgood)
plt.show()

# %%
liquidfuelgood=[0]*5
liquidfuelbad=[0]*5
for i in range(0, 5):
    temp1=co2liquidfuel[dataset['Country Name']==column0[i]].tolist()
    temp2=co2liquidfuel[dataset['Country Name']==column00[i]].tolist()
    liquidfuelgood[i]=(temp1[8]-temp1[0])
    liquidfuelbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,liquidfuelbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,liquidfuelgood)
plt.show()

# %%
liquidfuelgood=[0]*5
liquidfuelbad=[0]*5
for i in range(0, 5):
    temp1=co2liquidfuel[dataset['Country Name']==column0[i]].tolist()
    temp2=co2liquidfuel[dataset['Country Name']==column00[i]].tolist()
    liquidfuelgood[i]=(temp1[8]-temp1[0])
    liquidfuelbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,liquidfuelbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,liquidfuelgood)
plt.show()

# %%
liquidfuelgood=[0]*5
liquidfuelbad=[0]*5
for i in range(0, 5):
    temp1=co2liquidfuel[dataset['Country Name']==column0[i]].tolist()
    temp2=co2liquidfuel[dataset['Country Name']==column00[i]].tolist()
    liquidfuelgood[i]=(temp1[8]-temp1[0])
    liquidfuelbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,liquidfuelbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,liquidfuelgood)
plt.show()

# %%
liquidfuelgood=[0]*5
liquidfuelbad=[0]*5
for i in range(0, 5):
    temp1=co2liquidfuel[dataset['Country Name']==column0[i]].tolist()
    temp2=co2liquidfuel[dataset['Country Name']==column00[i]].tolist()
    liquidfuelgood[i]=(temp1[8]-temp1[0])
    liquidfuelbad[i]=(temp2[8]-temp2[0])
plt.xlabel('country')
plt.ylabel('change in co2 edmission')
plt.bar(column00,liquidfuelbad)
plt.show()

plt.xlabel('country')
plt.ylabel('percentage change in CO2 edmission from 2007 to 2016')
plt.bar(column0,liquidfuelgood)
plt.show()
